# %%
# !pip install transformers
# !pip install hazm
# !pip install faiss-gpu==1.6.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.2-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 29.3 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 66.2 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 61.4 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.9.1 tokenizers-0.12.1 transformers-4.21.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hazm
#   Downloading hazm-0.7.0-py3-none-any.whl (316 kB)
#      |████████████████████████████████| 316 kB 29.7 MB/s
# Collecting libwapiti>=0.2.1
#   Downloading libwapiti-0.2.1.tar.gz (233 kB)
#      |████████████████████████████████| 233 kB 69.8 MB/s
# Collecting nltk==3.3
#   Downloading nltk-3.3.0.zip (1.4 MB)
#      |████████████████████████████████| 1.4 MB 40.1 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk==3.3->hazm) (1.15.0)
# Building wheels for collected packages: nltk, libwapiti
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.3-py3-none-any.whl size=1394487 sha256=54e9945092776c30f3920a67870ea711f403da5e54bfb2fe071d90cc076d8add
#   Stored in directory: /root/.cache/pip/wheels/9b/fd/0c/d92302c876e5de87ebd7fc0979d82edb93e2d8d768bf71fac4
#   Building wheel for libwapiti (setup.py) ... done
#   Created wheel for libwapiti: filename=libwapiti-0.2.1-cp37-cp37m-linux_x86_64.whl size=155070 sha256=7706098fd79c8ac267760f4258dafa61078e10c10c483b6823c8c3f823f6dbf0
#   Stored in directory: /root/.cache/pip/wheels/ab/b2/5b/0fe4b8f5c0e65341e8ea7bb3f4a6ebabfe8b1ac31322392dbf
# Successfully built nltk libwapiti
# Installing collected packages: nltk, libwapiti, hazm
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# Successfully installed hazm-0.7.0 libwapiti-0.2.1 nltk-3.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting faiss-gpu==1.6.3
#   Downloading faiss_gpu-1.6.3-cp37-cp37m-manylinux2010_x86_64.whl (35.5 MB)
#      |████████████████████████████████| 35.5 MB 284 kB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from faiss-gpu==1.6.3) (1.21.6)
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.6.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_dir = "drive/MyDrive/UNI/CS/Term4/NLP/final_project/"

# %%
import codecs
import tqdm

mesra_collection = [x.strip().split() for x in tqdm.tqdm(codecs.open(F'{path_dir}/qazals/all_qazals_mesra.txt','rU','utf-8').readlines())]
train_mesras = mesra_collection[:20000]
test_mesras = mesra_collection[20000:20025]
# Out:
# 100%|██████████| 329707/329707 [00:00<00:00, 397570.52it/s]

# %% [markdown]
# **Preprocessing**

# %%
from __future__ import unicode_literals
from hazm import *

normalizer = Normalizer()
lemmatizer = Lemmatizer()

mesra_normalized = [[normalizer.normalize(y) for y in x] for x in tqdm.tqdm(train_mesras)]
mesra_sentences = [sent_tokenize(' '.join(x))[0] for x in tqdm.tqdm(mesra_normalized)]

test_mesra_normalized = [[normalizer.normalize(y) for y in x] for x in tqdm.tqdm(test_mesras)]
test_mesra_sentences = [sent_tokenize(' '.join(x))[0] for x in tqdm.tqdm(test_mesra_normalized)]
# Out:
# 100%|██████████| 20000/20000 [00:04<00:00, 4208.00it/s]
# 100%|██████████| 20000/20000 [00:00<00:00, 132452.40it/s]
# 100%|██████████| 25/25 [00:00<00:00, 3198.93it/s]
# 100%|██████████| 25/25 [00:00<00:00, 68894.61it/s]

# %% [markdown]
# **Importing and Initializing the Model**

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
from transformers import AdamW,pipeline
from torch.utils.data import DataLoader

tokenizer = AutoTokenizer.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")
model = AutoModelForMaskedLM.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")
# Out:
# Downloading config.json:   0%|          | 0.00/434 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/624M [00:00<?, ?B/s]
# Some weights of the model checkpoint at HooshvareLab/bert-base-parsbert-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model_inputs = tokenizer(mesra_sentences,
          add_special_tokens =True,
          padding='max_length',
          max_length=512,
          truncation=True,
          return_token_type_ids =False,
          return_tensors = 'pt',)
model_inputs.input_ids.shape
# Out:
# torch.Size([20000, 512])

# %%
import torch
model_inputs['labels'] = model_inputs.input_ids.detach().clone()
masks = (torch.rand(model_inputs.input_ids.shape) < .15) *\
        (model_inputs.input_ids != tokenizer.cls_token_id) *\
        (model_inputs.input_ids != tokenizer.sep_token_id) *\
        (model_inputs.input_ids != tokenizer.pad_token_id)
selection = []
for i in range(masks.shape[0]):
    selection.append(torch.flatten(masks[i].nonzero()).tolist())
#selection[0:5]

# %%
for i in range(masks.shape[0]):
    model_inputs.input_ids[i,selection[i]] = tokenizer.mask_token_id

# %%
class NewsDataset(torch.utils.data.Dataset):

    def __init__(self,encodings):
        self.encodings = encodings

    def __getitem__(self,idx):
        return {key : torch.tensor(val[idx]) for key,val in self.encodings.items()}
    
    def __len__(self): 
        return len(self.encodings['input_ids'])
dataset = NewsDataset(model_inputs)
train_dataloader = DataLoader(dataset , shuffle=True, batch_size= 4)

# %%
# %%capture
model.train() #activating training mode
optimizer = AdamW(model.parameters(), lr=5e-5)

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)
device
# Out:
# device(type='cuda')

# %% [markdown]
# **Training the Model**

# %%
mode_="test"
path_dir = "/drive/MyDrive/UNI/CS/Term4/NLP/final_project/"

if mode_=="train":
    
    epochs = 3
    from tqdm import tqdm
    for epoch in range(epochs):
        loop = tqdm(train_dataloader, leave = True)
        for batch in loop:
            optimizer.zero_grad()
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            output = model(input_ids=input_ids,attention_mask = attention_mask,labels = labels)
            loss = output.loss
            loss.backward()
            optimizer.step()
            loop.set_description(f'Epoch:{epoch}')
            loop.set_postfix(loss = loss.item())

else:
    model.load_state_dict(torch.load("drive/MyDrive/UNI/CS/Term4/NLP/final_project/parsbert_finetuned_mesra"))

# %%
# torch.save(model.state_dict(), "drive/MyDrive/UNI/CS/Term4/NLP/final_project/parsbert_finetuned_mesra")

# %%
#for encoding we delete Mhead
model.cls= torch.nn.Identity()

# %%
def input_to_feature(input_,model):
    text_preprocessed = input_
    encoded = tokenizer.batch_encode_plus([text_preprocessed],max_length=50, padding='max_length', truncation=True)
    encoded = {key:torch.LongTensor(value) for key, value in encoded.items()}
    encoded['input_ids']=encoded['input_ids'].cuda()
    encoded['token_type_ids']=encoded['token_type_ids'].cuda()
    encoded['attention_mask']=encoded['attention_mask'].cuda()
    with torch.no_grad(): 
            outputs = model(**encoded)
    feature_outputs = outputs[0].mean(1)
    return feature_outputs


def training_set_feature_bank(model,Data):
        
    feature_bank=[]
 
    batch_size = 10  
    for idx in range(0, len(Data ), batch_size):
        batch = Data [idx : min(len( Data), idx+batch_size)]
        
        # encoded = tokenizer(batch)
        
        encoded = tokenizer.batch_encode_plus(batch,max_length=50, padding='max_length', truncation=True)
    
        encoded = {key:torch.LongTensor(value) for key, value in encoded.items()}
        encoded['input_ids']=encoded['input_ids'].cuda()
        encoded['token_type_ids']=encoded['token_type_ids'].cuda()
        encoded['attention_mask']=encoded['attention_mask'].cuda()

        with torch.no_grad():
            
            outputs = model(**encoded)
            
            feature_bank.append(outputs[0].mean(1))

    feature_bank_t=torch.cat(feature_bank)
    return feature_bank_t

# %% [markdown]
# # Testing the Model

# %% [markdown]
# **evaluate test sentences**

# %%
model.eval()
feature_bank = training_set_feature_bank(model, mesra_sentences)
test_feature_bank = training_set_feature_bank(model, test_mesra_sentences)

# %%
from sklearn.neighbors import NearestNeighbors

def find_most_similar(_test_sentences_embedding, _train_sentences_embedding, _number_of_neighbors):
  knn = NearestNeighbors(n_neighbors=_number_of_neighbors)
  knn.fit(_train_sentences_embedding)
  most_similar = knn.kneighbors(_test_sentences_embedding) 
  return most_similar

# %%
most_similar = find_most_similar(test_feature_bank.cpu(), feature_bank.cpu(), 10)

# %%
for main_sent_index, main_sent in enumerate(most_similar[1]):
  print("\n مصرع اصلی شماره " + str(main_sent_index) + ":‌ " + test_mesra_sentences[main_sent_index])
  for close_sent_index, close_sent in enumerate(main_sent):
    print(str(close_sent_index) + " : " + mesra_sentences[close_sent])
# Out:
#  مصرع اصلی شماره 0:‌ که نه امشب آن سماعست که دف خلاص یابد
# 0 : نه آن شبست که کس در میان ما گنجد
# 1 : هر که با شاهد گلروی به خلوت بنشست
# 2 : نشان عاشق آن باشد که شب با روز پیوندد
# 3 : که گر چه رنج به جان می‌رسد امید دواست
# 4 : که قیامت رسد این رشته به هم یا نرسد
# 5 : که می‌رود به شفاعت که دوست بازآرد
# 6 : که گفته‌ست که صد دل به غمزه‌ای ببری
# 7 : هر که با مستان نشیند ترک مستوری کند
# 8 : هر آن دل را که پنهانی قرینی هست روحانی
# 9 : که دل اهل نظر برد که سریست خدایی
#
#  مصرع اصلی شماره 1:‌ به طپانچه‌ای و بربط برهد به گوشمالی
# 0 : به طمع ز دست رفتی و به پای درفکندت
# 1 : به قول مطرب و ساقی برون رفتم گه و بی‌گه
# 2 : سرو می‌نازد و خوش نیست خدا را بخرام
# 3 : دلق حافظ به چه ارزد به می‌اش رنگین کن
# 4 : صبا به غالیه سایی و گل به جلوه گری
# 5 : راکبی تندست و مرکوبی جمام
# 6 : که دست صبر برپیچید و بشکست
# 7 : ور نه بسیار بجویی و نیابی بازم
# 8 : بر لب جوی طرب جوی و به کف ساغر گیر
# 9 : تو مستریح و به افسوس می‌رود ایام
#
#  مصرع اصلی شماره 2:‌ دگر آفتاب رویت منمای آسمان را
# 0 : چه پروای سخن گفتن بود مشتاق خدمت را
# 1 : ای دلیل دل گمگشته خدا را مددی
# 2 : رونق عهد شباب است دگر بستان را
# 3 : چنان مرغ دلم را صید کردی
# 4 : پیش رویت دگران صورت بر دیوارند
# 5 : دگر رغبت کجا ماند کسی را سوی هشیاری
# 6 : کز دلم یک باره برد آرام را
# 7 : وقعیست ای برادر نه زهد پارسا را
# 8 : غایت جهل بود مشت زدن سندان را
# 9 : اکنون همان پنداشتم دریای بی پایاب را
#
#  مصرع اصلی شماره 3:‌ که قمر ز شرمساری بشکست چون هلالی
# 0 : که قمر چون رخ منیر تو نیست
# 1 : شوخی نرگس نگر که پیش تو بشکفت
# 2 : عمریست تا ز زلف تو بویی شنیده‌ام
# 3 : بس پریشانی بباید بردنش چون موی دوست
# 4 : خوشست با غم هجران دوست سعدی را
# 5 : که چشم سعی ضعیفست بی چراغ هدایت
# 6 : بر آفتاب که امشب خوشست با قمرم
# 7 : زهی رفیق که با چون تو سروبالاییست
# 8 : چون تیر ناگهان ز کنارم بجست یار
# 9 : کنون که مست خرابم صلاح بی‌ادبیست
#
#  مصرع اصلی شماره 4:‌ خط مشک بوی و خالت به مناسبت تو گویی
# 0 : زخم شمشیر غمت را به شکیبایی و عقل
# 1 : چو گل هر دم به بویت جامه در تن
# 2 : به خدا و به سراپای تو کز دوستیت
# 3 : ز رنگ و بوی تو ای سروقد سیم اندام
# 4 : مردمان از در و بامت به تماشا آیند
# 5 : گو دلم حق وفا با خط و خالت دارد
# 6 : تو خرسند و شکیبایی چنینت در خیال آید
# 7 : که گل به بوی تو بر تن چو صبح جامه درید
# 8 : بی خویشتنم کردی بوی گل و ریحان‌ها
# 9 : تو می‌روی و مرا چشم و دل به جانب توست
#
#  مصرع اصلی شماره 5:‌ قلم غبار می‌رفت و فروچکید خالی
# 0 : برق غیرت بدرخشید و جهان برهم زد
# 1 : بگذشت و باز آتش در خرمن سکون زد
# 2 : حافظا چون غم و شادی جهان در گذر است
# 3 : از تیر چرخ و سنگ فلاخن بتر بود
# 4 : همه شب ذکر تو می‌رفت و مکرر می‌شد
# 5 : و اندر آن آینه صد گونه تماشا می‌کرد
# 6 : نفسی می‌زد و آفاق منور می‌شد
# 7 : برق دولت که برفت از نظرم بازآید
# 8 : گل وجود من آغشته گلاب و نبید
# 9 : از سر اختران کهن سیر و ماه نو
#
#  مصرع اصلی شماره 6:‌ تو هم این مگوی سعدی که نظر گناه باشد
# 0 : سخن پیدا بود سعدی که حدش تا کجا باشد
# 1 : عجب از کسی در این شهر که پارسا بماند
# 2 : نه تو گفته‌ای که سعدی نبرد ز دست من جان
# 3 : حافظ از فقر مکن ناله که گر شعر این است
# 4 : کدام عیب که سعدی خود این هنر دارد
# 5 : ز چشم مست تو واجب کند که هشیاران
# 6 : مرا مگوی که سعدی طریق عشق رها کن
# 7 : تو گمان نیک بردی که من این گناه دارم
# 8 : مگوی سعدی از این درد جان نخواهد برد
# 9 : که فکری در درون ما از این بهتر نمی‌گیرد
#
#  مصرع اصلی شماره 7:‌ گنه‌ست برگرفتن نظر از چنین جمالی
# 0 : دیده از دیدار خوبان برگرفتن مشکلست
# 1 : عجب فتادن مردست در کمند غزال
# 2 : دل داده را ملامت گفتن چه سود دارد
# 3 : مردم چشمش بدرد پرده اعمی ز شوق
# 4 : از شوق آن حریم ندارد سر حجاز
# 5 : حافظ نه حد ماست چنین لاف‌ها زدن
# 6 : از قفا باید برون کردن زبان سوسنش
# 7 : پرده از سر برگرفتیم آن همه تزویر را
# 8 : مؤمن ز دست عشق تو زنار برگرفت
# 9 : گنجیست درج در عقیقین آن پسر
#
#  مصرع اصلی شماره 8:‌ ترحم ذلتی یا ذا المعالی
# 0 : الیک قلبی یا غایه المنی صاب
# 1 : حماک الله یا عهد التلاقی
# 2 : یسر الله طریقا بک یا ملتمسی
# 3 : مبر فرمان بدگوی بدآموز
# 4 : یا لیت شعری حتام القاه
# 5 : یا برید الحمی حماک الله
# 6 : افتتح یا مفتح الابواب
# 7 : غریق العشق فی بحر الوداد
# 8 : یا بخت من طریق مروت فروگذاشت
# 9 : شخصی کما ترانی من غایه اشتیاقی
#
#  مصرع اصلی شماره 9:‌ و واصلنی اذا شوشت حالی
# 0 : و واصلنی علی رغم الاعادی
# 1 : و روحی کل یوم لی ینادی
# 2 : و اندر عقبت قلوب و ابصار
# 3 : زان جان و دلم همی فکارست
# 4 : بنده معتقد و چاکر دولتخواهم
# 5 : و ان هجرت سواء عشیتی غداتی
# 6 : و غر نه او بنی آنچت نشادی
# 7 : و آبگینست پیش سندانت
# 8 : و ذکرک مونسی فی کل حال
# 9 : و دار باللوی فوق الرمال
#
#  مصرع اصلی شماره 10:‌ الا یا ناعس الطرفین سکری
# 0 : الا تعسا لایام الفراق
# 1 : یا غریب الحسن رفقا بالغریب
# 2 : یا بخت من طریق مروت فروگذاشت
# 3 : یا عشوه همی‌دهد خیالم
# 4 : یا رب دعای خسته دلان مستجاب کن
# 5 : حماک الله یا عهد التلاقی
# 6 : الیک قلبی یا غایه المنی صاب
# 7 : افتتح یا مفتح الابواب
# 8 : بجز ثنای جلالش مساز ورد ضمیر
# 9 : یا لیت شعری حتام القاه
#
#  مصرع اصلی شماره 11:‌ سل السهران عن طول اللیالی
# 0 : مبر فرمان بدگوی بدآموز
# 1 : سادتی احترق القلب من الاشواق
# 2 : فاسالوا حالها عن الاطلال
# 3 : خلیانی نحو منظوری اقف
# 4 : الا تعسا لایام الفراق
# 5 : علی التمام فروخوانم الحدیث یطول
# 6 : سلام الله ما کر اللیالی
# 7 : لو اضافوا صحف الدهر الی اوراقی
# 8 : مرضیه السجایا محموده الخصائل
# 9 : بضرب سیفک قتلی حیاتنا ابدا
#
#  مصرع اصلی شماره 12:‌ ندارم چون تو در عالم دگر دوست
# 0 : آدمی چون تو در آفاق نشان نتوان داد
# 1 : سوزناک افتاده چون پروانه‌ام در پای تو
# 2 : که جز تو در همه عالم کسی دگر دارد
# 3 : سخن‌ها دارم از دست تو در دل
# 4 : بسته‌ام در خم گیسوی تو امید دراز
# 5 : هنوز مهر تو باشد در استخوان ای دوست
# 6 : آرزو می‌کندم در همه عالم صیدی
# 7 : بازآ که در فراق تو چشم امیدوار
# 8 : من از دست تو در عالم نهم روی
# 9 : چون من در آن دیار هزاران غریب هست
#
#  مصرع اصلی شماره 13:‌ اگر چه دوستی دشمن فعالی
# 0 : اگر چه مدعی بیند حقیرم
# 1 : هر چه بینی ز دوستان کرمست
# 2 : گر چه بدنامیست نزد عاقلان
# 3 : اگر چه رسم خوبان تندخوییست
# 4 : از دوستان جانی مشکل توان بریدن
# 5 : هشیار کسی باید کز عشق بپرهیزد
# 6 : گفت ای عاشق بیچاره تو باری چه کسی
# 7 : از ملامت چه غم خورد سعدی
# 8 : اگر چه همچو سگم هرزه لای می‌داند
# 9 : چه چاره سازد در دام دل گرفتاری
#
#  مصرع اصلی شماره 14:‌ کمال الحسن فی الدنیا مصون
# 0 : توکلنا علی رب العباد
# 1 : غریق العشق فی بحر الوداد
# 2 : تعالی خالق الانسان من طین
# 3 : صرف الله عنک عین کمال
# 4 : احمد الله علی معدله السلطان
# 5 : الله الله تو فراموش مکن عهد قدیم
# 6 : یحیی بن مظفر ملک عالم عادل
# 7 : فحبک راحتی فی کل حین
# 8 : خورشید سایه پرور طرف کلاه تو
# 9 : جمال چهره تو حجت موجه ماست
#
#  مصرع اصلی شماره 15:‌ کمثل البدر فی حد الکمال
# 0 : فی جمال الکمال نلت منی
# 1 : قصه العشق لا انفصام لها
# 2 : سادتی احترق القلب من الاشواق
# 3 : مرضیه السجایا محموده الخصائل
# 4 : غریق العشق فی بحر الوداد
# 5 : حماک الله یا عهد التلاقی
# 6 : فاسالوا حالها عن الاطلال
# 7 : الا تعسا لایام الفراق
# 8 : نفسی تزول عاقبه الامر فی الهوی
# 9 : کتاب بالغ منی حبیبا معرضا عنی
#
#  مصرع اصلی شماره 16:‌ مرکب در وجودم همچو جانی
# 0 : همچو من دست در گریبان داشت
# 1 : ما در درون سینه هوایی نهفته‌ایم
# 2 : همچو حافظ غریب در ره عشق
# 3 : نخواهی دید در دوزخ عذابی
# 4 : نه چنان در کمند پیچیدی
# 5 : آن چنان وهم در تو حیرانست
# 6 : بجوی از مردم صاحب کمالش
# 7 : در این خرقه بسی آلودگی هست
# 8 : عاقل از فتنه می‌کند حذری
# 9 : من با تو بسی شمار دارم
#
#  مصرع اصلی شماره 17:‌ مصور در دماغم چون خیالی
# 0 : خیالش در نظر چون آیدم خواب
# 1 : چون آب در آبگینه پیداست
# 2 : ما در آثار صنع حیرانیم
# 3 : حیرتم در صفات بی چونست
# 4 : که سرفرازی عالم در این کله دانست
# 5 : ما در درون سینه هوایی نهفته‌ایم
# 6 : زیباتر از تو در نظرم هیچ منظری
# 7 : خیال نقش تو در کارگاه دیده کشیدم
# 8 : همچو حافظ غریب در ره عشق
# 9 : چون آدمی طمع نکند در سماحتش
#
#  مصرع اصلی شماره 18:‌ فما ذالنوم قیل النوم راحه
# 0 : الیک قلبی یا غایه المنی صاب
# 1 : بشری اذ السلامه حلت بذی سلم
# 2 : علی التمام فروخوانم الحدیث یطول
# 3 : یرسم المنظور قتلی ارتضی فیما امر
# 4 : اذا تغرد عن ذی الاراک طائر خیر
# 5 : فلا تفرد عن روضها انین حمامی
# 6 : وجدت رائحه الود ان شممت رفاتی
# 7 : لله حمد معترف غایه النعم
# 8 : لا تلومونی فجرحی ما التحم
# 9 : لو اضافوا صحف الدهر الی اوراقی
#
#  مصرع اصلی شماره 19:‌ و مالی النوم فی طول اللیالی
# 0 : و دار باللوی فوق الرمال
# 1 : و ذکرک مونسی فی کل حال
# 2 : و روحی کل یوم لی ینادی
# 3 : و غر نه او بنی آنچت نشادی
# 4 : و ان هجرت سواء عشیتی غداتی
# 5 : و ادعو بالتواتر و التوالی
# 6 : لم ازل عبدا و اوصالی رمم
# 7 : و قد تفتش عین الحیوه فی الظلمات
# 8 : و اندر عقبت قلوب و ابصار
# 9 : فحبک راحتی فی کل حین
#
#  مصرع اصلی شماره 20:‌ دمی دلداری و صاحب دلی کن
# 0 : صد جان فدای یار نصیحت نیوش کن
# 1 : روزی دو به خدمت آشنا کن
# 2 : هر سحر از عشق دمی می‌زنم
# 3 : بنشین و قبای بسته وا کن
# 4 : برو شادی کن ای یار دل افروز
# 5 : خرما دور وصالی و خوشا درد دلی
# 6 : زیبا همه روز گو جفا کن
# 7 : غلام همت شنگولیان و رندانم
# 8 : غلام همت رندان و پاکبازانم
# 9 : خواهی که زلف یار کشی ترک هوش کن
#
#  مصرع اصلی شماره 21:‌ که برخور بادی از صاحب جمالی
# 0 : که بندد طرف وصل از حسن شاهی
# 1 : دم از ممالک خوبی چو آفتاب زدن
# 2 : که دست دادش و یاری ناتوانی داد
# 3 : که با حکم خدایی کینه داری
# 4 : که با خود عشق بازد جاودانه
# 5 : هر نقش که دست عقل بندد
# 6 : که سختی بینی و جور آزمایی
# 7 : خون پیاله خور که حلال است خون او
# 8 : بجوی از مردم صاحب کمالش
# 9 : برود جان مستمند از تن
#
#  مصرع اصلی شماره 22:‌ الم تنظر الی عینی و دمعی
# 0 : و روحی کل یوم لی ینادی
# 1 : لا ابالی ان دعالی او شتم
# 2 : لم ازل عبدا و اوصالی رمم
# 3 : ان ترد محو البرایا فانکشف
# 4 : بضرب سیفک قتلی حیاتنا ابدا
# 5 : زهی حیات نکونام و رفتنی به شهادت
# 6 : غلام آصف ثانی جلال الحق و الدینم
# 7 : صرف الله عنک عین کمال
# 8 : و ما ابری نفسی و لا ازکیها
# 9 : اعتقادی بنما و بگذر بهر خدا
#
#  مصرع اصلی شماره 23:‌ تری فی البحر اصداف اللالی
# 0 : سادتی احترق القلب من الاشواق
# 1 : فاسالوا حالها عن الاطلال
# 2 : لو اضافوا صحف الدهر الی اوراقی
# 3 : الیک قلبی یا غایه المنی صاب
# 4 : غریق العشق فی بحر الوداد
# 5 : خلیانی نحو منظوری اقف
# 6 : بلغ الطاقه یا مقله عینی بینی
# 7 : حماک الله یا عهد التلاقی
# 8 : الا تعسا لایام الفراق
# 9 : یسر الله طریقا بک یا ملتمسی
#
#  مصرع اصلی شماره 24:‌ به گوشت گر رسانم ناله زار
# 0 : حرف‌ها بینی آلوده به خون جگرم
# 1 : ور چو دفم پوست بدرد قفا
# 2 : گر به دست آید آب حیوانم
# 3 : گر بکشندش نمی‌رود به دگر جا
# 4 : به قصد جان من زار ناتوان انداخت
# 5 : زین سفر گر به سلامت به وطن بازرسم
# 6 : گر برسد ناله سعدی به کوه
# 7 : ناله زاریدنش آید به گوش
# 8 : به مگسران ملامت ز کنار شکرم
# 9 : گر به کاشانه رندان قدمی خواهی زد

# %% [markdown]
# **Testing one sentence**

# %%
single_test_mesra_sentence = ["چراغ مرده شمع آفتاب"]
single_test_feature_bank = training_set_feature_bank(model, single_test_mesra_sentence)
single_test_most_similar = find_most_similar(single_test_feature_bank.cpu(), feature_bank.cpu(), 10)

# %%
for main_sent_index, main_sent in enumerate(single_test_most_similar[1]):
  print("\n مصرع اصلی شماره " + str(main_sent_index) + ":‌ " + single_test_mesra_sentence[main_sent_index])
  for close_sent_index, close_sent in enumerate(main_sent):
    print(str(close_sent_index) + " : " + mesra_sentences[close_sent])
# Out:
#  مصرع اصلی شماره 0:‌ چراغ مرده شمع آفتاب
# 0 : چراغ مرده کجا شمع آفتاب کجا
# 1 : شمع فلک با هزار مشعل انجم
# 2 : مه پیکر آفتاب پرتو
# 3 : آفتاب حسن او تا شعله زد
# 4 : چراغ دولتش نوری ندارد
# 5 : پرده برانداز شبی شمع وار
# 6 : چراغ صاعقه آن سحاب روشن باد
# 7 : نور ستارگان ستد روی چو آفتاب تو
# 8 : ببار ای شمع اشک از چشم خونین
# 9 : پیش بمیرد چراغدان ثریا
